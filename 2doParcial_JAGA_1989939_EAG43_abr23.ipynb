# %% [markdown]
# ## Segundo Examen Parcial  de Estadística Aplicada
# Enero-Junio 2023

# %% [markdown]
# **Nombre:** José Alfonso González Acosta
#
# **Matricula:** 1989939

# %% [markdown]
# **Instrucciones:** En cada punto importa las librerias que consideres necesarias.

# %%
# Importa las librerias de numpy, python y matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# importa la base de datos llamada credit_risk.csv
# https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/credit_risk.csv
datos = pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/credit_risk.csv')
datos
# Out:
#     checking_account_status  duration        credit_history  \
# 0                   below_0         6      critical_account
# 1                  0_to_200        48  existing_credit_paid
# 2                no_account        12      critical_account
# 3                   below_0        42  existing_credit_paid
# 4                   below_0        24       delay_in_paying
# ..                      ...       ...                   ...
# 995              no_account        12  existing_credit_paid
# 996                 below_0        30  existing_credit_paid
# 997              no_account        12  existing_credit_paid
# 998                 below_0        45  existing_credit_paid
# 999                0_to_200        45      critical_account
#
#                  purpose  amount savings_account_status employment_years  \
# 0               radio_TV    1169                unknown          above_7
# 1               radio_TV    5951              below_100      between_1_4
# 2              education    2096              below_100      between_4_7
# 3    furniture_equipment    7882              below_100      between_4_7
# 4                car_new    4870              below_100      between_1_4
# ..                   ...     ...                    ...              ...
# 995  furniture_equipment    1736              below_100      between_4_7
# 996             car_used    3857              below_100      between_1_4
# 997             radio_TV     804              below_100          above_7
# 998             radio_TV    1845              below_100      between_1_4
# 999             car_used    4576        between_100_500       unemployed
#
#      installment_rate personal_status other_debtors  ...          property  \
# 0                   4        M_single          None  ...      real_estate
# 1                   2    F_not_single          None  ...      real_estate
# 2                   2        M_single          None  ...      real_estate
# 3                   2        M_single     guarantor  ...  life_insurance
# 4                   3        M_single          None  ...       no_property
# ..                ...             ...           ...  ...               ...
# 995                 3    F_not_single          None  ...      real_estate
# 996                 4      M_divorced          None  ...  life_insurance
# 997                 4        M_single          None  ...             other
# 998                 4        M_single          None  ...       no_property
# 999                 3        M_single          None  ...             other
#
#     age  other_installment_plans housing number_of_credits         job  \
# 0    67                     None     own                 2    official
# 1    22                     None     own                 1    official
# 2    49                     None     own                 1   unskilled
# 3    45                     None    free                 1    official
# 4    53                     None    free                 2    official
# ..   ..                      ...     ...               ...         ...
# 995  31                     None     own                 1   unskilled
# 996  40                     None     own                 1  management
# 997  38                     None     own                 1    official
# 998  23                     None    free                 1    official
# 999  27                     None     own                 1    official
#
#     people_liable  telephone  foreign_worker  full_repaid
# 0               1          1               1            1
# 1               1          0               1            0
# 2               2          0               1            1
# 3               2          0               1            1
# 4               2          0               1            0
# ..            ...        ...             ...          ...
# 995             1          0               1            1
# 996             1          1               1            1
# 997             1          0               1            1
# 998             1          1               1            0
# 999             1          0               1            1
#
# [1000 rows x 21 columns]

# %% [markdown]
# La base de datos es la información proporcionada por un banco donde nos muestra el tiempo que transcurre desde que un cliente pide un préstamo hasta que lo paga completamente (evento).
#
# A continuación se muestran la descripción de la base de datos.

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-fymr{border-color:inherit;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-fymr">   <br>Característica   </th>
#     <th class="tg-fymr">   <br>Variable   </th>
#     <th class="tg-fymr">   <br>Tipo   </th>
#     <th class="tg-fymr">   <br>Descripción   </th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">   <br>Time   </td>
#     <td class="tg-0pky">   <br>duration   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Duration in month   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Event   </td>
#     <td class="tg-0pky">   <br>full_repaid   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Specifies if the loan was fully   repaid   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>age   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Age of the borrower (in years)   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>foreign_worker   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Indicates if the borrower is a   foreign worker   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>personal_status   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Gender and Marital status   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>people_liable   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Number of people being liable to   provide maintenance for   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>telephone   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Indicates if the borrower owns a   phone   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Employment   </td>
#     <td class="tg-0pky">   <br>employment_years   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Years of employment at current job   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Employment   </td>
#     <td class="tg-0pky">   <br>job   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Employment status   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Residence   </td>
#     <td class="tg-0pky">   <br>housing   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Residential status of the borrower   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Residence   </td>
#     <td class="tg-0pky">   <br>present_residence   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Years living at current residence   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Loan   information   </td>
#     <td class="tg-0pky">   <br>amount   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Amount of money borrowed   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Loan   information   </td>
#     <td class="tg-0pky">   <br>installment_rate   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Percentage of amount borrowed that   will be charged by a lender to a borrower.   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Loan   information   </td>
#     <td class="tg-0pky">   <br>purpose   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Reason to get a loan   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>checking_account_status   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Status of the checking account   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>credit_history   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Credit history of the borrower   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>number_of_credits   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Number of existing credits at this   bank   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>other_installment_plans   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Type of installments plans the   borrower already has   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>savings_account_status   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Status of the saving account   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Collateral/Guarantor   </td>
#     <td class="tg-0pky">   <br>property   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Type of valuable assets the   borrower owns   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Collateral/Guarantor   </td>
#     <td class="tg-0pky">   <br>other_debtors   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Indicate if someone else will be   involved in the repayment or is guaranteeing the loan   </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     1. El banco sospecha que entre mas pasa el tiempo más díficil es que puedan pagar los clientes que se les concedió un préstamo.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     a) Calcula el promedio del monto del préstamo de los que pagaron y el promedio del monto de los que no han pagado.

# %%
si_pago = datos[datos['full_repaid']==1]
si_pago.describe()
# Out:
#          duration        amount  installment_rate  present_residence  \
# count  700.000000    700.000000        700.000000         700.000000
# mean    19.207143   2985.457143          2.920000           2.842857
# std     11.079564   2401.472278          1.128078           1.108373
# min      4.000000    250.000000          1.000000           1.000000
# 25%     12.000000   1375.500000          2.000000           2.000000
# 50%     18.000000   2244.000000          3.000000           3.000000
# 75%     24.000000   3634.750000          4.000000           4.000000
# max     60.000000  15857.000000          4.000000           4.000000
#
#               age  number_of_credits  people_liable   telephone  \
# count  700.000000         700.000000     700.000000  700.000000
# mean    36.224286           1.424286       1.155714    0.415714
# std     11.381145           0.584721       0.362844    0.493197
# min     19.000000           1.000000       1.000000    0.000000
# 25%     27.000000           1.000000       1.000000    0.000000
# 50%     34.000000           1.000000       1.000000    0.000000
# 75%     42.250000           2.000000       1.000000    1.000000
# max     75.000000           4.000000       2.000000    1.000000
#
#        foreign_worker  full_repaid
# count      700.000000        700.0
# mean         0.952857          1.0
# std          0.212096          0.0
# min          0.000000          1.0
# 25%          1.000000          1.0
# 50%          1.000000          1.0
# 75%          1.000000          1.0
# max          1.000000          1.0

# %%
no_pago = datos[datos['full_repaid']==0]
no_pago.describe()
# Out:
#          duration        amount  installment_rate  present_residence  \
# count  300.000000    300.000000        300.000000         300.000000
# mean    24.860000   3938.126667          3.096667           2.850000
# std     13.282639   3535.818955          1.088395           1.094605
# min      6.000000    433.000000          1.000000           1.000000
# 25%     12.000000   1352.500000          2.000000           2.000000
# 50%     24.000000   2574.500000          4.000000           3.000000
# 75%     36.000000   5141.500000          4.000000           4.000000
# max     72.000000  18424.000000          4.000000           4.000000
#
#               age  number_of_credits  people_liable   telephone  \
# count  300.000000         300.000000     300.000000  300.000000
# mean    33.963333           1.366667       1.153333    0.376667
# std     11.222379           0.559702       0.360911    0.485360
# min     19.000000           1.000000       1.000000    0.000000
# 25%     25.000000           1.000000       1.000000    0.000000
# 50%     31.000000           1.000000       1.000000    0.000000
# 75%     40.000000           2.000000       1.000000    1.000000
# max     74.000000           4.000000       2.000000    1.000000
#
#        foreign_worker  full_repaid
# count      300.000000        300.0
# mean         0.986667          0.0
# std          0.114889          0.0
# min          0.000000          0.0
# 25%          1.000000          0.0
# 50%          1.000000          0.0
# 75%          1.000000          0.0
# max          1.000000          0.0

# %% [markdown]
# **RESPUESTA:** <br>
# El promedio de monto de préstamo para las personas que **SI** pagaron fue de **2985.46**. <br>
# El promedio de monto de préstamo para las personas que **NO** pagaron fue de **3938.13**.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     b) Ajusta un modelo weibull y un modelo log-normal y graficas las funciones de riesgo respectivas.

# %%
from lifelines import WeibullFitter

# %%
weib = WeibullFitter().fit(datos['duration'],datos['full_repaid'])

# %% [markdown]
# **RESPUESTA:** <br>
# Función de Riesgo **Modelo Weibull:**

# %%
weib.plot_hazard()
# Out:
# <AxesSubplot:>

# %%
from lifelines import LogNormalFitter

# %%
logn = LogNormalFitter().fit(datos['duration'],datos['full_repaid'])

# %% [markdown]
# **RESPUESTA:** <br>
# Función de Riesgo **Log Normal:**

# %%
logn.plot_hazard()
# Out:
# <AxesSubplot:>

# %%
weib.AIC_.round(), logn.AIC_.round()
# Out:
# (5901.0, 5814.0)

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     c) comenta que significa la grafica de la función de riesgo de la weibull respecto a si los clientes tardan en pagar.

# %% [markdown]
# **RESPUESTA:** <br>
# Significa que entre más tiempo tarde la persona en pagar, mayor es la probabilidad de que **NO** pague.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     d) comenta que significa la grafica de la función de riesgo de la log-normal respecto a si los clientes tardan en pagar.

# %% [markdown]
# **RESPUESTA:** <br>
# Significa que los préstamos de entre 20 y 30 meses aproximadamente, tienen la mayor probabilidad de que **NO** sean pagados esos préstamos.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     2. Estima la función de supervivencia por el método de Kaplan-Meier para el tiempo que tardan los clientes en pagar y muestra su gráfica correspondiente.

# %%
from lifelines import KaplanMeierFitter

# %%
km_datos = KaplanMeierFitter().fit(datos['duration'],datos['full_repaid'])

# %% [markdown]
# **RESPUESTA:**

# %%
km_datos.plot_survival_function(label = "Full-repaid")
plt.xlabel('Duración del préstamo')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     3. Coloca la gráfica de kaplan Meier sobre la grafica de supervivencia log-normal.

# %%
logn.plot_survival_function(label='Full_repaid',color='red')
km_datos.plot_survival_function(label='Full_repaid',color='green')
plt.xlabel('Duración del préstamo')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     4. Comenta si las graficas se parecen o no, y en que se diferencian.

# %% [markdown]
# **RESPUESTA:** <br>
# Las gráficas **SI** se parecen. A lo largo del tiempo de duración del préstamo, se comportan prácticamente de manera idéntica.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     5. El banco considera que los que piden préstado una gran cantidad de dinero en realidad nunca piensa pagar.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     a) Calcula la mediana de la cantidad que pidieron prestado (amount of money borrowed), asigna un 1 a quienes se encuentran igual o arriba de la mediana (deben mucho) y 0 a los que se encuentran debajo de la mediana (deben poco).

# %%
import statistics

# %%
mediana = statistics.median(datos['amount'])
print("La mediana de cantidad de dinero prestado es de", median)
# Out:
# La mediana de cantidad de dinero prestado es de 2319.5

# %%
median = datos['amount'].median()

datos['median_situation'] = np.where(datos['amount'] >= median, 1, 0)
datos
# Out:
#     checking_account_status  duration        credit_history  \
# 0                   below_0         6      critical_account
# 1                  0_to_200        48  existing_credit_paid
# 2                no_account        12      critical_account
# 3                   below_0        42  existing_credit_paid
# 4                   below_0        24       delay_in_paying
# ..                      ...       ...                   ...
# 995              no_account        12  existing_credit_paid
# 996                 below_0        30  existing_credit_paid
# 997              no_account        12  existing_credit_paid
# 998                 below_0        45  existing_credit_paid
# 999                0_to_200        45      critical_account
#
#                  purpose  amount savings_account_status employment_years  \
# 0               radio_TV    1169                unknown          above_7
# 1               radio_TV    5951              below_100      between_1_4
# 2              education    2096              below_100      between_4_7
# 3    furniture_equipment    7882              below_100      between_4_7
# 4                car_new    4870              below_100      between_1_4
# ..                   ...     ...                    ...              ...
# 995  furniture_equipment    1736              below_100      between_4_7
# 996             car_used    3857              below_100      between_1_4
# 997             radio_TV     804              below_100          above_7
# 998             radio_TV    1845              below_100      between_1_4
# 999             car_used    4576        between_100_500       unemployed
#
#      installment_rate personal_status other_debtors  ...  housing  \
# 0                   4        M_single          None  ...      own
# 1                   2    F_not_single          None  ...      own
# 2                   2        M_single          None  ...      own
# 3                   2        M_single     guarantor  ...     free
# 4                   3        M_single          None  ...     free
# ..                ...             ...           ...  ...      ...
# 995                 3    F_not_single          None  ...      own
# 996                 4      M_divorced          None  ...      own
# 997                 4        M_single          None  ...      own
# 998                 4        M_single          None  ...     free
# 999                 3        M_single          None  ...      own
#
#     number_of_credits         job people_liable telephone  foreign_worker  \
# 0                   2    official             1         1               1
# 1                   1    official             1         0               1
# 2                   1   unskilled             2         0               1
# 3                   1    official             2         0               1
# 4                   2    official             2         0               1
# ..                ...         ...           ...       ...             ...
# 995                 1   unskilled             1         0               1
# 996                 1  management             1         1               1
# 997                 1    official             1         0               1
# 998                 1    official             1         1               1
# 999                 1    official             1         0               1
#
#     full_repaid  relacion_mediana  amount_vs_median  median_situation
# 0             1                 0                 0                 0
# 1             0                 1                 1                 1
# 2             1                 0                 0                 0
# 3             1                 1                 1                 1
# 4             0                 1                 1                 1
# ..          ...               ...               ...               ...
# 995           1                 0                 0                 0
# 996           1                 1                 1                 1
# 997           1                 0                 0                 0
# 998           0                 0                 0                 0
# 999           1                 1                 1                 1
#
# [1000 rows x 24 columns]

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     b) Elabora y grafica juntas las funciones de supervivencia por el método de Kaplan-Meier para los que deben mucho y para los que deben poco.

# %%
bm = datos.query('median_situation==0')
km_bm = KaplanMeierFitter().fit(bm['duration'], bm['full_repaid'])

sm = datos.query('median_situation==1')
km_sm = KaplanMeierFitter().fit(sm['duration'], sm['full_repaid'])

km_bm.plot_survival_function(ci_show = False, label = 'Mayor a la mediana',color='blue')
km_sm.plot_survival_function(ci_show = False, label = 'Menor a la mediana',color='purple')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     c) Interpreta las graficas de supervivencia, ¿qué significan? ¿quién paga más rápido? ¿quién tarda en pagar más?

# %% [markdown]
# **RESPUESTA:** <br> Los que pagan mas rápido son aquellos cuyos montos están por debajo de la mediana, mientras que los que están por encima de la mediana, se podría decir que son aquellos que no piensan pagar, que realmente es que demoran demasiado tiempo.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     d) Elabora un log-rank test para comprobar si las funciones de supervivencia de los que deben mucho y los que deben poco son distintas, e interpreta el resultado de la prueba.

# %%
lrt = logrank_test(bm['duration'], sm['duration'],
                   bm['full_repaid'], sm['full_repaid'])
lrt.print_summary()
# Out:
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#          199.26 <0.005    147.89

# %% [markdown]
# **RESPUESTA:** <br> Rechazamos H0 ya que el p-valor de el log-rank test es menor a 0.05, por lo que las funciones son distintas entre si. Aquellos que están en montos sobre la media, tendrán a demorar en pagar (y quizá hasta no llegar a pagar).

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     e) ¿El banco tenía razón? Explique.

# %% [markdown]
# **RESPUESTA:** <br>
# Sí, en efecto los prestamos de mayor tiempo son los que tienden a demorar más tiempo en pagar (o incluso hasta no llegar a hacerlo), mientras que los de menor tiempo se pagan con mayor probabilidad.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     6. Elige seis variables para ajustar un modelo de cox de riesgos porporcionales. Antes de correr el modelo explica en qué sentido y por qué afectan el riesgo de pagar el préstamo cada una de las variables elegidas.

# %% [markdown]
# **6 VARIABLES:**
#
# **age:** Entre mayor sea una persona, tiene mayor capacidad de pago, así como experiencia con préstamos/bancos, a diferencia de una persona joven e inexperta.
# <br>
#
# **telephone:** Al solicitar un préstamo, la información personal del cliente es vital. Ayuda a mantener contacto y llegar a un acuerdo cuando se requiera ajustar el periodo o el monto del mismo.
# <br>
#
# **number of credits:** Suponiendo que la cantidad de créditos solicitados afecta el cumpliento de pago de estos.
# <br>
#
# **people liable:** Suponiendo que si una persona tiene mas personas a las que proveer, si incapacidad de pago aumentará. Por otro lado, podría decirse que una persona proveedora, tiene mayor y mejor vida financiera.
#
# **foreign worker:** Si una persona trabaja en el extranjero, el tipo de cambio puede generar dificultades para hacer frente a los pagos del préstamo.
# <br>
#
# **amount:** Entre mayor sea el monto del préstamo solicitado, mayores serán las dificultades de hacer frente a los pagos.

# %%
from lifelines import CoxPHFitter

# %% [markdown]
# **I) AGE**

# %%
age = datos[['duration', 'age', 'full_repaid']]

cox_age = CoxPHFitter().fit(age, 'duration', 'full_repaid')
cox_age.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4266.36
#          time fit was run = 2023-04-04 06:10:11 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age         0.01       1.01       0.00             0.00             0.01                 1.00                 1.01
#
#             cmp to    z    p   -log2(p)
# covariate
# age           0.00 2.49 0.01       6.31
# ---
# Concordance = 0.54
# Partial AIC = 8534.72
# log-likelihood ratio test = 6.05 on 1 df
# -log2(p) of ll-ratio test = 6.17

# %% [markdown]
# **II) Telephone**

# %%
telephone = datos[['duration', 'telephone', 'full_repaid']]

cox_tel = CoxPHFitter().fit(telephone, 'duration', 'full_repaid')
cox_tel.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4265.43
#          time fit was run = 2023-04-04 06:18:59 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# telephone  -0.22       0.81       0.08            -0.37            -0.06                 0.69                 0.94
#
#             cmp to     z    p   -log2(p)
# covariate
# telephone     0.00 -2.80 0.01       7.60
# ---
# Concordance = 0.55
# Partial AIC = 8532.86
# log-likelihood ratio test = 7.91 on 1 df
# -log2(p) of ll-ratio test = 7.67

# %% [markdown]
# **III) Number of Credits**

# %%
number_credits = datos[['duration', 'number_of_credits', 'full_repaid']]

cox_nuc = CoxPHFitter().fit(number_credits, 'duration', 'full_repaid')
cox_nuc.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4268.82
#          time fit was run = 2023-04-04 06:28:57 UTC
#
# ---
#                     coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# number_of_credits   0.07       1.07       0.07            -0.06             0.20                 0.94                 1.22
#
#                     cmp to    z    p   -log2(p)
# covariate
# number_of_credits     0.00 1.07 0.29       1.81
# ---
# Concordance = 0.50
# Partial AIC = 8539.65
# log-likelihood ratio test = 1.12 on 1 df
# -log2(p) of ll-ratio test = 1.79

# %% [markdown]
# **IV) People Liable**

# %%
people_liable = datos[['duration', 'people_liable', 'full_repaid']]

cox_pel = CoxPHFitter().fit(people_liable, 'duration', 'full_repaid')
cox_pel.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4269.28
#          time fit was run = 2023-04-04 06:40:25 UTC
#
# ---
#                 coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# people_liable   0.05       1.05       0.10            -0.16             0.25                 0.85                 1.29
#
#                 cmp to    z    p   -log2(p)
# covariate
# people_liable     0.00 0.45 0.65       0.61
# ---
# Concordance = 0.51
# Partial AIC = 8540.57
# log-likelihood ratio test = 0.20 on 1 df
# -log2(p) of ll-ratio test = 0.61

# %% [markdown]
# **V) Foreign Worker**

# %%
foreign = datos[['duration', 'foreign_worker', 'full_repaid']]

cox_for = CoxPHFitter().fit(foreign, 'duration', 'full_repaid')
cox_for.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4253.74
#          time fit was run = 2023-04-04 06:14:55 UTC
#
# ---
#                  coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# foreign_worker  -1.18       0.31       0.18            -1.54            -0.83                 0.22                 0.44
#
#                  cmp to     z      p   -log2(p)
# covariate
# foreign_worker     0.00 -6.58 <0.005      34.32
# ---
# Concordance = 0.53
# Partial AIC = 8509.48
# log-likelihood ratio test = 31.29 on 1 df
# -log2(p) of ll-ratio test = 25.42

# %% [markdown]
# **VI) Amount**

# %%
amount = datos[['duration', 'amount', 'full_repaid']]

cox_amo = CoxPHFitter().fit(amount, 'duration', 'full_repaid')
cox_amo.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4124.50
#          time fit was run = 2023-04-04 06:14:08 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# amount     -0.00       1.00       0.00            -0.00            -0.00                 1.00                 1.00
#
#             cmp to      z      p   -log2(p)
# covariate
# amount        0.00 -14.03 <0.005     146.03
# ---
# Concordance = 0.73
# Partial AIC = 8250.99
# log-likelihood ratio test = 289.78 on 1 df
# -log2(p) of ll-ratio test = 213.45

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     7. Interpreta la regresión de Cox.

# %% [markdown]
# Prueba de Hipótesis <br>
# **H0:** Bi = 0 <br>
# **H1:** Bi = 0 <br>
# Si **p-value < alpha (0.05)**,
# Rechazamos H0.

# %% [markdown]
# **I) Age:** p-valor = **0.01**, por lo tanto **Rechazamos H0.** Dado que la variable es significativa, podemos concluir con un 95% de confianza que la edad **SI** influye en la capacidad de pago de un préstamo.
#
# **II) Telephone:** p-valor = **0.01**, por lo tanto **Rechazamos H0.** Dado que la variable es significativa, podemos concluir con un 95% de confianza que tener información personal del cliente y estar en contacto **SI** influye en la capacidad de pago de un préstamo.
#
# **III) Number of credits:** p-valor = **0.29**, por lo tanto **NO Rchazamos H0.** Dado que la variable no es significativa, podemos concluir con un 95% de confianza que la cantidad de creditos solicitados **NO** influye en la capacidad de pago de estos prestamos.
#
# **IV) People Liable:** p-valor = **0.65**, por lo tanto **NO Rechazamos H0.** Dado que la variable no es significativa, podemos concluir con un 95% de confianza que la cantidad de personas a las que una persona proveé **NO** influye en la capacidad de pago de un préstamo.
#
# **V) Foreign Worker:** p-valor = **<0.005**, por lo tanto **Rechazamos H0.** Dado que la variable es significativa, podemos concluir con un 95% de confianza que trabajar en el extranjero **SI** influye en la capacidad de pago de un préstamo.
#
# **VI) Amount:** p-valor = **<0.005**, por lo tanto **Rechazamos H0.** Dado que la variable es significativa, podemos concluir con un 95% de confianza que el monto de un préstamo **SI** influye en la capacidad de pago del mismo.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     8. Con base en el análisis hecho hasta ahora qué recomendación podría hacer al banco para mejorar sus políticas de préstamo.

# %% [markdown]
# **RESPUESTA:** <br>
# Recomendaría aplicar más y mejores filtros a los clientes, contar con una base de datos completa con información personal, y un eficiente historial que determine el riesgo que puede traer un x cliente para la empresa.
#
# En los préstamos, el riesgo no solo recae en quien toma prestado el dinero, si no también para quien lo presta. Sería importante contar la información de estas personas así como su experiencia con clientes. Si sus clientes demoran en pagar o no lo hacen, puede ser que el foco rojo venga desde la raíz de quien esta otorgando el préstamo, y puede prevenirse a tiempo.
