# %% [markdown]
# # Sesión 13
# ## Estadistica Aplicada
# **Jose Alfonso Gonzalez Acosta**
# - 22 de marzo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ponch\anaconda3\lib\site-packages (0.2.13)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (2.3.6)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: requests>=2.26 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ponch\anaconda3\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ponch\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\ponch\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\ponch\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\ponch\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ponch\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ponch\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ponch\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ponch\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ponch\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: pycparser in c:\users\ponch\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import yfinance as yf

# %%
ticker = 'AMZN.MX'

# %%
amazon = yf.download('AMZN.MX',
                    start = '2019-01-01',
                    end = '2023-03-17',
                    progress = False)

# %%
amazon.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-02  1451.000000  1522.499512  1451.000000  1497.750000  1497.750000
# 2019-01-03  1507.400024  1507.400024  1472.250000  1474.000000  1474.000000
# 2019-01-04  1500.449951  1541.362549  1496.500000  1527.000000  1527.000000
# 2019-01-07  1550.000000  1581.000000  1539.500000  1578.361450  1578.361450
# 2019-01-08  1612.531006  1612.531006  1570.910034  1605.208984  1605.208984
#
#             Volume
# Date
# 2019-01-02  462900
# 2019-01-03  143880
# 2019-01-04   43580
# 2019-01-07   66960
# 2019-01-08  127960

# %%
amazon = amazon[['Adj Close']]

# %%
amazon.head()
# Out:
#               Adj Close
# Date
# 2019-01-02  1497.750000
# 2019-01-03  1474.000000
# 2019-01-04  1527.000000
# 2019-01-07  1578.361450
# 2019-01-08  1605.208984

# %%
amazon = amazon.rename(columns={'Adj Close':'precio_cierre'})
amazon.head()
# Out:
#             precio_cierre
# Date
# 2019-01-02    1497.750000
# 2019-01-03    1474.000000
# 2019-01-04    1527.000000
# 2019-01-07    1578.361450
# 2019-01-08    1605.208984

# %%
amazon['MA-10'] = amazon['precio_cierre'].rolling(window=10).mean()

# %%
amazon['precio_cierre'].plot()
plt.title('Precio de la acción en Amazon\n 2019-2023')
plt.ylabel('pesos MXN')
plt.show()

# %%
amazon['MA-10'] = amazon['precio_cierre'].rolling(window=10).mean()
amazon['MA-60'] = amazon['precio_cierre'].rolling(window=60).mean()

# %%
amazon[['MA-10', 'MA-60']].plot()
plt.title('Señal de Largo Plazo vs Corto Plazo')
plt.ylabel('pesos MXN')
plt.show()
